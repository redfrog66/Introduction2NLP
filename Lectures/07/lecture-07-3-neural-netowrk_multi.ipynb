# %% [markdown]
# # Neural Network - multiclass classification

# %% [markdown]
# ## Read the data

# %%
import pandas as pd

df_train = pd.read_json("../data/news_train.json", orient="records")
df_train.info()
df_train.hist()
df_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4560 entries, 0 to 4559
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        4560 non-null   object
#  1   label       4560 non-null   int64
#  2   label_name  4560 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 107.0+ KB
#                                                 text  label label_name
# 0  The Organization of the Petroleum Exporting Co...      0   Business
# 1  American business tycoon Malcolm Glazer has in...      2     Sports
# 2  NEW YORK (Reuters) - International Business Ma...      1    SciTech
# 3  Unilever, the world #39;s largest maker of foo...      0   Business
# 4  Australia #39;s Nathan Baggaley was over the m...      2     Sports

# %%
df_val = pd.read_json("../data/news_val.json", orient="records")
df_val.info()
df_val.hist()
df_val.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        1520 non-null   object
#  1   label       1520 non-null   int64
#  2   label_name  1520 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 35.8+ KB
#                                                 text  label label_name
# 0  The first hearing in the re-trial of former le...      3      World
# 1  Intel #39;s board has given the go ahead for t...      0   Business
# 2  Stocks closed higher on Wall Street as investo...      0   Business
# 3  Even with a boost from higher oil prices and g...      0   Business
# 4  Vornado Realty Trust said on Friday it has acq...      0   Business

# %%
df_test = pd.read_json("../data/news_test.json", orient="records")
df_test.info()
df_test.hist()
df_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        1520 non-null   object
#  1   label       1520 non-null   int64
#  2   label_name  1520 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 35.8+ KB
#                                                 text  label label_name
# 0  While rivals scramble to catch up on the deskt...      1    SciTech
# 1  AP - UCLA soccer coach Jillian Ellis was happy...      2     Sports
# 2  PCI Express allows Nvidia to tap into system m...      1    SciTech
# 3  AP - The Federal Election Commission on Thursd...      3      World
# 4  City officials hope there are people willing t...      1    SciTech

# %% [markdown]
# ## Preprocessing data

# %%
pip install nltk

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

STOPWORDS = stopwords.words("english")

def is_html_tag(word):
    w = word.replace("\n", "")
    return w.startswith("<") or w.startswith(">") or w.startswith("/") or w.strip()[:2] == "br"

def remove_html_tags(sentence):
    single_spaces = " ".join(sentence.split())

    return " ".join([token for token in single_spaces.split(" ") if not is_html_tag(token)])

def tokenize_sentence(sentence):
    return word_tokenize(sentence.lower())

def remove_stopwords(sentence):
    return " ".join([word for word in sentence.split(" ") if not word in STOPWORDS])

def remove_punctuation(tokenized_sentence):
    return [word for word in tokenized_sentence if word.isalpha()]

def preprocess(sentence):
    return remove_punctuation(tokenize_sentence(remove_stopwords(remove_html_tags(str(sentence)))))

print(preprocess(df_train["text"].values[1]))
# Out:
# ['american', 'business', 'tycoon', 'malcolm', 'glazer', 'increased', 'stake', 'manchester', 'united', 'buying', 'another', 'worth', 'shares', 'club']

# %%
df_train["text"] = df_train["text"].apply(preprocess)
df_train.head()
# Out:
#                                                 text  label label_name
# 0  [the, organization, petroleum, exporting, coun...      0   Business
# 1  [american, business, tycoon, malcolm, glazer, ...      2     Sports
# 2  [new, york, reuters, international, business, ...      1    SciTech
# 3  [unilever, world, s, largest, maker, food, soa...      0   Business
# 4  [australia, s, nathan, baggaley, moon, winning...      2     Sports

# %%
def build_vocab(tokenized_input, vocab_size):
    d = dict()

    for tokens in tokenized_input:
        for token in tokens:
            # double check
            if token not in STOPWORDS and token.isalpha():
                d[token] = d.get(token, 0) + 1

    del d["br"]

    return {k for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)[:vocab_size]}

# %%
VOCAB_SIZE = 10000
VOCAB = build_vocab(df_train["text"].values, VOCAB_SIZE) # (!) Always build the vocabulary on the TRAIN dataset

# %%
len(VOCAB)
# Out:
# 10000

# %%
LABELS = df_train["label"].unique()
LABELS
# Out:
# array([0, 2, 1, 3], dtype=int64)

# %%
LABELS_TO_NAMES = {label: df_train[df_train["label"] == label].iloc[0]["label_name"] for label in LABELS}
LABELS_TO_NAMES
# Out:
# {0: 'Business', 2: 'Sports', 1: 'SciTech', 3: 'World'}

# %%
def get_frequencies_for_labels(df):
    dict_freqs = {label: {} for label in LABELS}

    for idx in range(df.shape[0]):
        tokens = df.iloc[idx, 0]
        label = df.iloc[idx, 1]
        
        for token in tokens:
            if token in VOCAB:
                dict_freqs[label][token] = dict_freqs[label].get(token, 0) + 1
            

    return dict_freqs

# %%
frequency_table = get_frequencies_for_labels(df_train)
frequency_table[0]["money"]
# Out:
# 9

# %%
import numpy as np

def extract_features(frequency_table, tweet_tokens):
    label_frequencies = {label: 0 for label in LABELS}

    for t in tweet_tokens:
        for label in LABELS:
            label_frequencies[label] += frequency_table[label].get(t, 0)
    
    return pd.Series(label_frequencies)

# %%
X_train = df_train["text"].apply(lambda tokens: extract_features(frequency_table, tokens))
X_train
# Out:
#          0    2    1    3
# 0      598  192  199  205
# 1      232  239  100  143
# 2     1313  824  889  962
# 3      449  133  208   80
# 4      176  557  144  188
# ...    ...  ...  ...  ...
# 4555    76   12   19    9
# 4556   711  432  329  736
# 4557   158  824  172  282
# 4558   316  175  181  222
# 4559   656  296  354  391
#
# [4560 rows x 4 columns]

# %%
y_train = df_train["label"].values
y_train
# Out:
# array([0, 2, 1, ..., 2, 0, 3], dtype=int64)

# %%
X_val = df_val["text"].apply(preprocess)
X_val = df_val["text"].apply(lambda tokens: extract_features(frequency_table, tokens))
y_val = df_val["label"].values
X_val
# Out:
#        0   2   1   3
# 0     78  64  50  33
# 1     80  69  79  33
# 2     52  50  55  23
# 3     55  43  83  25
# 4     46  36  47  18
# ...   ..  ..  ..  ..
# 1515  82  60  53  33
# 1516  56  42  32  19
# 1517  65  42  88  16
# 1518  49  33  48  13
# 1519  46  40  32  23
#
# [1520 rows x 4 columns]

# %% [markdown]
# ## Create model and train / validate

# %%
pip install tensorflow

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(4,)),
    tf.keras.layers.Dense(128),
    tf.keras.layers.Dense(64),
    tf.keras.layers.Dense(units=4, activation='softmax')
])

model.compile(optimizer='adam',
              loss="sparse_categorical_crossentropy",
              metrics=['accuracy'])
              
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               640
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 9,156
# Trainable params: 9,156
# Non-trainable params: 0
# _________________________________________________________________

# %%
h = model.fit(X_train,
              y_train,
              epochs=10,
              batch_size=32,
              validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 143/143 [==============================] - 3s 17ms/step - loss: 11.2097 - accuracy: 0.6999 - val_loss: 5.0274 - val_accuracy: 0.2507
# Epoch 2/10
# 143/143 [==============================] - 0s 3ms/step - loss: 4.7159 - accuracy: 0.7475 - val_loss: 4.9074 - val_accuracy: 0.2743
# Epoch 3/10
# 143/143 [==============================] - 0s 3ms/step - loss: 4.0378 - accuracy: 0.7517 - val_loss: 3.8153 - val_accuracy: 0.2493
# Epoch 4/10
# 143/143 [==============================] - 0s 2ms/step - loss: 3.6744 - accuracy: 0.7435 - val_loss: 6.1908 - val_accuracy: 0.2750
# Epoch 5/10
# 143/143 [==============================] - 0s 2ms/step - loss: 4.5968 - accuracy: 0.7400 - val_loss: 2.9743 - val_accuracy: 0.2520
# Epoch 6/10
# 143/143 [==============================] - 0s 2ms/step - loss: 3.3249 - accuracy: 0.7456 - val_loss: 5.2280 - val_accuracy: 0.2678
# Epoch 7/10
# 143/143 [==============================] - 0s 2ms/step - loss: 3.2745 - accuracy: 0.7510 - val_loss: 2.8505 - val_accuracy: 0.2553
# Epoch 8/10
# 143/143 [==============================] - 0s 2ms/step - loss: 4.4961 - accuracy: 0.7214 - val_loss: 5.2692 - val_accuracy: 0.2539
# Epoch 9/10
# 143/143 [==============================] - 0s 2ms/step - loss: 3.1988 - accuracy: 0.7276 - val_loss: 2.6066 - val_accuracy: 0.2507
# Epoch 10/10
# 143/143 [==============================] - 0s 2ms/step - loss: 2.4288 - accuracy: 0.7329 - val_loss: 3.2300 - val_accuracy: 0.2520

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['loss'], label='(training data)',color='blue')
plt.plot(h.history['val_loss'], label='(validation data)',color='green')
plt.title('Neural Network training loss')
plt.ylabel('value')
plt.xlabel('No. epoch')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['accuracy'], label='(training data)',color='blue')
plt.plot(h.history['val_accuracy'], label='(validation data)',color='green')
plt.title('Neural Network training accuracy')
plt.ylabel('value')
plt.xlabel('No. epoch')
plt.show()

# %% [markdown]
# ## Evaluate the trained model

# %%
X_test = df_test["text"].apply(preprocess)
X_test = df_test["text"].apply(lambda tokens: extract_features(frequency_table, tokens))
y_test = df_test["label"].values
X_test
# Out:
#        0   2    1   3
# 0     56  55   95  20
# 1     69  64  112  32
# 2     54  48  109  24
# 3     66  62   81  32
# 4     96  83  129  43
# ...   ..  ..  ...  ..
# 1515  96  61  168  30
# 1516  83  58   73  27
# 1517  86  64  126  31
# 1518  40  28   40  25
# 1519  51  34   67  21
#
# [1520 rows x 4 columns]

# %%
results = model.evaluate(X_test, y_test, batch_size=50)
print("test loss, test acc:", results)
# Out:
# 31/31 [==============================] - 0s 2ms/step - loss: 3.1699 - accuracy: 0.2553
# test loss, test acc: [3.1699059009552, 0.25526314973831177]

# %%
df_test_raw = pd.read_json("../data/news_test.json", orient="records")

# %%
predictions = np.round(model.predict(X_test[:100]))
for i in range(len(predictions)):
    print(df_test_raw["text"].values[i][:100],"...")
    print("Pred: ", predictions[i], "Real: ", y_test[i])
# Out:
# While rivals scramble to catch up on the desktop, Google plans to digitize famous libraries. Its off ...
# Pred:  [0. 1. 0. 0.] Real:  1
# AP - UCLA soccer coach Jillian Ellis was happy to beat her best friend, Princeton counterpart Julie  ...
# Pred:  [0. 1. 0. 0.] Real:  2
# PCI Express allows Nvidia to tap into system memory to save expensive on-board graphics memory and a ...
# Pred:  [0. 1. 0. 0.] Real:  1
# AP - The Federal Election Commission on Thursday elected a new chairman and vice chairman, choosing  ...
# Pred:  [0. 1. 0. 0.] Real:  3
# City officials hope there are people willing to pay plenty of money to own a vintage Playboy Bunny c ...
# Pred:  [0. 1. 0. 0.] Real:  1
# KIEV (Reuters) - Ukrainian Prime Minister Viktor Yanukovich  said on Saturday he would stand against ...
# Pred:  [1. 0. 0. 0.] Real:  3
# AFP - French auto giant Renault SA said it will invest some 570 million dollars in South Korea over  ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Buffalo Bills offensive coordinator Tom Clements has emerged on a short list of candidates whom Notr ...
# Pred:  [1. 0. 0. 0.] Real:  2
# The \$500 billion drug industry is stumbling badly in its core business of finding new medicines, wh ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Google has launched Google Scholar, a search service aimed specifically at the academic community. T ...
# Pred:  [0. 1. 0. 0.] Real:  1
# Qwest Communications may not be immediately affected by a Sprint-Nextel merger, but its options coul ...
# Pred:  [0. 1. 0. 0.] Real:  0
# Two researchers say they #39;ve discovered a pattern of tremors deep beneath the San Andreas Fault t ...
# Pred:  [1. 0. 0. 0.] Real:  1
# Toothpaste maker Colgate-Palmolive said today it is cutting 4,400 jobs and closing a third of its 78 ...
# Pred:  [0. 1. 0. 0.] Real:  0
# KEY talks between the government of Sudan and rebels in the troubled Darfur region tomorrow could fa ...
# Pred:  [0. 1. 0. 0.] Real:  3
# US troops injured in Iraq have required limb amputations at twice the rate of past wars, and as many ...
# Pred:  [0. 1. 0. 0.] Real:  3
# KABUL, Dec 8 (AFP) - NATO-led troops in Afghanistan will not scale back their presence before parlia ...
# Pred:  [0. 1. 0. 0.] Real:  3
# AstraZeneca intends to invest over 120m in Cambridge Antibody Technology (CAT) through an innovative ...
# Pred:  [0. 1. 0. 0.] Real:  0
# US scientists had made a breakthrough in their quest to make low-cost hydrogen, a technology key to  ...
# Pred:  [1. 0. 0. 0.] Real:  1
# 25/11/2004 - The first in a completely new class of drug for multiple sclerosis has been approved in ...
# Pred:  [0. 1. 0. 0.] Real:  0
# The ACLU files Freedom of Information Act requests to find out why antiterrorism task forces have be ...
# Pred:  [1. 0. 0. 0.] Real:  1
# IBM this week announced the formation of Power.org, a collaborative community of itself and 14 partn ...
# Pred:  [0. 1. 0. 0.] Real:  1
# Israel will not attend a Middle East conference in London early next year but backs its stated aim o ...
# Pred:  [0. 1. 0. 0.] Real:  3
# WALTHAM -- He is an 87-year-old man with a cane and a cigar, and the clout of a king. ...
# Pred:  [1. 0. 0. 0.] Real:  2
# Reuters - The Basque separatist group ETA set off\five bombs at petrol stations around Madrid on Fri ...
# Pred:  [0. 1. 0. 0.] Real:  3
# The Philippine economy continued to grow robustly in the third quarter despite rising consumer price ...
# Pred:  [0. 1. 0. 0.] Real:  0
# BAGHDAD (AFP) - Iraq #39;s electoral commission was due to study a call by top leaders to delay the  ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Microsoft #39;s MSN has introduced a beta version of its new blogging tool, MSN Spaces, which it exp ...
# Pred:  [0. 1. 0. 0.] Real:  1
# The sharp fall in the dollar on the foreign exchange markets - and the consequent rise in the value  ...
# Pred:  [0. 1. 0. 0.] Real:  0
# Oracle Corp. announced today it has signed a definitive merger agreement to acquire PeopleSoft Inc.  ...
# Pred:  [0. 1. 0. 0.] Real:  1
# President Bush meets with Italian Prime Minister Silvio Berlusconi in the Oval Office of the White H ...
# Pred:  [1. 0. 0. 0.] Real:  0
# The expected withdrawal from the Gaza Strip is substantively different from that which Israel will c ...
# Pred:  [0. 1. 0. 0.] Real:  3
# WASHINGTON - November was the bloodiest month for US troops in Iraq since April, with at least 135 l ...
# Pred:  [0. 1. 0. 0.] Real:  3
# &lt;p&gt;\&lt;/p&gt;&lt;p&gt; By Lisa Baertlein&lt;/p&gt;&lt;p&gt; SAN FRANCISCO (Reuters) - A forme ...
# Pred:  [0. 1. 0. 0.] Real:  1
# Thousands of protesters marched peacefully through downtown Santiago on Friday, expressing anger at  ...
# Pred:  [0. 1. 0. 0.] Real:  3
# AP - While manager Joe Torre repeatedly dodged questions Thursday on whether he thinks Jason Giambi  ...
# Pred:  [1. 0. 0. 0.] Real:  2
# In a move that has been dubbed as  #39;disastrous #39; by the Royal Society of Chemistry, Exeter Uni ...
# Pred:  [0. 1. 0. 0.] Real:  1
# AP - Premier Silvio Berlusconi, an important ally for President Bush in Iraq, was acquitted of corru ...
# Pred:  [0. 0. 0. 0.] Real:  3
# SiliconValley.com - Intel is making a big push to help personal computer makers in China and India o ...
# Pred:  [0. 1. 0. 0.] Real:  1
# MINNEAPOLIS -- One is a 6-foot-1 National Player of the Year candidate, looking to lead her top-rank ...
# Pred:  [1. 0. 0. 0.] Real:  2
# Feyenoord boss Ruud Gullit has launched a stinging attack on his players after watching them crash t ...
# Pred:  [1. 0. 0. 0.] Real:  2
# Two Qassam rockets landed in the western Negev on Saturday morning, causing damage to a home. No cas ...
# Pred:  [1. 0. 0. 0.] Real:  3
# Washington area biotech companies will face pivotal moments this year, finding out whether key produ ...
# Pred:  [0. 1. 0. 0.] Real:  0
# Danish security research firm Secunia has reported a vulnerability that occurs in most browsers that ...
# Pred:  [0. 1. 0. 0.] Real:  1
# The Nets reported deal for Vince Carter very much surprises me given New Jersey #39;s cost-slashing  ...
# Pred:  [1. 0. 0. 0.] Real:  2
# quot;Do you have it in your heart? How much guts do you have? How much do you hate to lose? quot;. T ...
# Pred:  [0. 1. 0. 0.] Real:  2
# AOL has added a range of features to ward off computer viruses, intrusive spyware programs and spam  ...
# Pred:  [0. 1. 0. 0.] Real:  1
# HARARE - The Zimbabwe government will not invite imperialist countries to observe its elections due  ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Yahoo Maps To Add Traffic Updates and Reports\\Yahoo is not only becoming the goto place for multime ...
# Pred:  [1. 0. 0. 0.] Real:  1
# Microsoft watched a software deal with China go bust less than two weeks into the contract. And Beij ...
# Pred:  [0. 1. 0. 0.] Real:  1
# Australia #39;s plan to establish a maritime surveillance zone that would cover much of Indonesia ha ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Reuters - Croatia's liberal President Stjepan\Mesic looked set to win a second term in elections on  ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Certain Pioneer TVs have a faulty power supply. An upgrade is available. ...
# Pred:  [0. 1. 0. 0.] Real:  1
# AP - North Korea on Saturday said its U.N. diplomats met U.S. officials in New York twice in the pas ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Reuters - U.N. Secretary-General Kofi\Annan on Monday chose the high-profile British head of a key\a ...
# Pred:  [1. 0. 0. 0.] Real:  3
# The Motion Picture Association of America is in talks with the Internet2 research consortium, hoping ...
# Pred:  [0. 1. 0. 0.] Real:  1
# \\Interesting data  this morning (thanks Dan ) on weblogs:\\"Blog readership shoots up 58 in 2004 6  ...
# Pred:  [0. 1. 0. 0.] Real:  1
# The US will offer an olive branch to Peter Mandelson, the European Union #39;s new trade commissione ...
# Pred:  [0. 1. 0. 0.] Real:  0
# David Beckham prevented a major incident between England #39;s fired-up players and their aggrieved  ...
# Pred:  [0. 1. 0. 0.] Real:  2
# Barcelona has moved 12 points clear at the top of Spain #39;s Primera Liga thanks to a 2-1 win at Al ...
# Pred:  [0. 1. 0. 0.] Real:  2
# An adult publishing company sued Google last week, alleging a dozen counts of copyright infringement ...
# Pred:  [0. 1. 0. 0.] Real:  1
# Company is expanding production to deliver more flat-panel TVs. ...
# Pred:  [0. 1. 0. 0.] Real:  1
# IBM is reportedly in talks to sell its personal computer business. It would mark the end of an era f ...
# Pred:  [0. 1. 0. 0.] Real:  0
# Egypt, Israel and the United States have reached an agreement that allows Egyptian industry to sell  ...
# Pred:  [1. 0. 0. 0.] Real:  3
# The UN Security Council on Tuesday condemned reported military actions by Rwanda in the eastern Demo ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Germany sends three planes to Sudan's troubled Darfur region to help deploy more African Union troop ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Entering the final week for Heisman Trophy voters to make their decision, the race has turned out ti ...
# Pred:  [1. 0. 0. 0.] Real:  2
# AP - A judge declined to dismiss charges against four men accused of distributing steroids to top at ...
# Pred:  [0. 1. 0. 0.] Real:  2
# Jeff Raikes was working at Apple Computer in the early 1980s when a guy named Steve Ballmer called a ...
# Pred:  [1. 0. 0. 0.] Real:  1
# (OfficialWire) -- 12/16/04 -- Britain #39;s highest court ruled Thursday against holding terror susp ...
# Pred:  [1. 0. 0. 0.] Real:  3
# Trust me, you don #39;t want to see desperate parents shopping over the holidays. I was at Circuit C ...
# Pred:  [0. 1. 0. 0.] Real:  1
# Dan Orlovsky threw for 283 yards and a touchdown in his final home game yesterday to lead Connecticu ...
# Pred:  [0. 1. 0. 0.] Real:  2
# ENGLEWOOD, Colo. (Sports Network) - Veteran defensive  tackle Luther Elliss of the Denver Broncos wi ...
# Pred:  [1. 0. 0. 0.] Real:  2
# Time Warner is to announce today that it will pay between \$500 and \$600 million to settle federal  ...
# Pred:  [1. 0. 0. 0.] Real:  0
# AP - Lawmakers fought over and failed to pass legal reforms aimed at ensuring a fair rematch of Ukra ...
# Pred:  [0. 0. 0. 0.] Real:  3
# Well, that didn #39;t go very well, did it? Everybody knew the NHL planned on turning down the NHLPA ...
# Pred:  [0. 1. 0. 0.] Real:  2
# Collard greens and black-eyed peas, a New Years tradition, on a chefs site; Virtual-Bubblewrap.com l ...
# Pred:  [0. 1. 0. 0.] Real:  1
# Reuters - NASA has finished building a redesigned\space shuttle fuel tank that was reconfigured to e ...
# Pred:  [0. 1. 0. 0.] Real:  1
# SEOUL (Reuters) - North Korea will not dismantle its  nuclear programs or improve ties with South Ko ...
# Pred:  [0. 1. 0. 0.] Real:  3
# Nextel and Sprint are in talks that could lead to a merger between the two mobile phone operators, s ...
# Pred:  [0. 1. 0. 0.] Real:  0
# Reuters - The leader of Sinn Fein, Northern\Ireland's main Catholic party and the political ally of  ...
# Pred:  [0. 1. 0. 0.] Real:  3
# AP - Sudan is prepared to halt military operations in the Darfur region if rebels withdraw from some ...
# Pred:  [0. 0. 0. 0.] Real:  3
# Security company F-Secure warned of a variant on the Skulls Trojan horse that infects smart phones r ...
# Pred:  [1. 0. 0. 0.] Real:  1
# This weekend Manchester City entertain Spurs, and with last seasons seven-goal FA Cup epic between t ...
# Pred:  [0. 1. 0. 0.] Real:  2
# One of the three women suing the University of Colorado for what they said was the school #39;s fail ...
# Pred:  [0. 1. 0. 0.] Real:  2
# Free agent first baseman Richie Sexson appears to be at the top of the Orioles' wish list after a me ...
# Pred:  [0. 1. 0. 0.] Real:  2
# short for  quot;Weblog quot; -- was the most-frequently requested definition at Merriam-Webster #39; ...
# Pred:  [0. 1. 0. 0.] Real:  1
# Telekom Austria, Austrias largest telecoms operator, obtained access to the relatively underdevelope ...
# Pred:  [0. 1. 0. 0.] Real:  0
# AP - Utah defensive coordinator Kyle Whittingham was hired as the school's football coach to replace ...
# Pred:  [0. 1. 0. 0.] Real:  2
# ATLANTA (Sports Network) - Isma #39;il Muhammad scored a team-high 14 points, Jarrett Jack added 13  ...
# Pred:  [1. 0. 0. 0.] Real:  2
# Halifax yesterday became the the first major lender to predict widespread falls in house prices acro ...
# Pred:  [0. 1. 0. 0.] Real:  0
# Chipmaker announces new chipset and reference design for consumer devices and PCs. ...
# Pred:  [1. 0. 0. 0.] Real:  1
# AURORA, Ore. The National Christmas Tree Association is hoping a push of designer trees will renew c ...
# Pred:  [1. 0. 0. 0.] Real:  0
# It #39;s the discovery by two Mars rovers that the Red Planet once had water and possibly could have ...
# Pred:  [0. 1. 0. 0.] Real:  1
# AP - Normally at this time of the year, labor contractor Jose Luis Avalos would be assembling a crew ...
# Pred:  [0. 1. 0. 0.] Real:  0
# AP - A government panel Wednesday approved plans to send a weather satellite into Earth's orbit by F ...
# Pred:  [0. 1. 0. 0.] Real:  1
# This was not an easy day on which to play cricket. The sun shone brilliantly enough but for all of t ...
# Pred:  [0. 1. 0. 0.] Real:  2
# Stephen Graham scores 16 points, including two late three-point plays, and No. 5 Oklahoma State beat ...
# Pred:  [0. 1. 0. 0.] Real:  2
# YASSER Arafat is dead. A so-called moderate is now chairman of the Palestine Liberation Organization ...
# Pred:  [1. 0. 0. 0.] Real:  3
# AP - Hours after a tsunami flattened south Asia beaches  #151; a magnet for thousands of vacationing ...
# Pred:  [1. 0. 0. 0.] Real:  3
# Cassini #39;s latest sweep past Saturn #39;s moon Titan revealed more intriguing pictures of the sur ...
# Pred:  [0. 1. 0. 0.] Real:  1
